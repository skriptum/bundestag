# %% [markdown]
# # Datenbereinigung

# %%
import pandas as pd
import plotly.express as px
import geopandas as gpd

# %%
#twitter account data
df = pd.read_csv("data/accounts_data.csv")
df = df.drop(columns = ["Unnamed: 0"])

#wahlkreise wahlergebnisse
wdata = pd.read_csv("data/wahl.csv", sep = ";")

#wahlkreise shapefiles
#wahlkreise shapefiles
gj = gpd.read_file("data/wahlkreise.geojson")

# %%
#better wahl data
wahl = wdata.copy()
wahl["Namen"] = wahl["Vorname"] + " " + wahl["Name"]
wahl = wahl.drop(columns=["Geburtsjahr", "Beruf", "Wiedergewählt", "Vorname", "Name"])
wahl = wahl.dropna()
wahl = wahl.rename(columns = {"Gewählt_Wahlkreis_Nr": "WKR_NR"} )

# %%
gp = pd.merge(gj, wahl, on="WKR_NR", how = "inner")

# %% [markdown]
# # exploration

# %%
gp.head()
# Out:
#    WKR_NR                           WKR_NAME           LAND_NAME LAND_NR  \
# 0       1              Flensburg - Schleswig  Schleswig-Holstein      01
# 1       2  Nordfriesland - Dithmarschen Nord  Schleswig-Holstein      01
# 2       3       Steinburg - Dithmarschen Süd  Schleswig-Holstein      01
# 3       4              Rendsburg-Eckernförde  Schleswig-Holstein      01
# 4       5                               Kiel  Schleswig-Holstein      01
#
#                                             geometry Partei_KurzBez  \
# 0  POLYGON ((9.10538 54.82926, 9.08154 54.81961, ...            CDU
# 1  MULTIPOLYGON (((8.73920 54.46810, 8.71693 54.4...            CDU
# 2  MULTIPOLYGON (((8.69891 54.04547, 8.69504 54.0...            CDU
# 3  POLYGON ((9.93690 54.63718, 9.93913 54.63358, ...            CDU
# 4  POLYGON ((10.16873 54.43279, 10.15766 54.42889...            SPD
#
#   Gewählt_Land              Gewählt_Wahlkreis_Bez                  Namen
# 0           SH              Flensburg – Schleswig       Petra Nicolaisen
# 1           SH  Nordfriesland – Dithmarschen Nord         Astrid Damerow
# 2           SH       Steinburg – Dithmarschen Süd          Mark Helfrich
# 3           SH              Rendsburg-Eckernförde  Johann David Wadephul
# 4           SH                               Kiel     Jens Mathias Stein

# %%
#twitter datei
df.head()
# Out:
#             name_id         screen_name        id  \
# 0    @johannesvogel      Johannes Vogel  15630931
# 1            @solms  Hermann Otto Solms  16325209
# 2   @florian_toncar      Florian Toncar  17462171
# 3  @ManuelHoeferlin     Manuel Höferlin  17483463
# 4   @christianduerr      Christian Dürr  17535941
#
#                                                 desc        creation_date  \
# 0  MdB, Generalsekretär der FDP NRW und Mitglied ...  2008-07-28 12:19:51
# 1  Mitglied des Deutschen Bundestages und Ehrenvo...  2008-09-17 07:49:56
# 2  Parlamentarischer Geschäftsführer & finanzpoli...  2008-11-18 10:55:06
# 3  Vors. Ausschuss Digitale Agenda @bundestag - D...  2008-11-19 10:16:23
# 4  Fraktionsvize bei der @fdpbt | Haushalt & Fina...  2008-11-21 13:20:23
#
#                                          profile_pic  num_followers  \
# 0  https://pbs.twimg.com/profile_images/106524014...          19423
# 1  https://pbs.twimg.com/profile_images/112539605...           7500
# 2  https://pbs.twimg.com/profile_images/120506699...           6110
# 3  https://pbs.twimg.com/profile_images/912621016...           6411
# 4  https://pbs.twimg.com/profile_images/112864255...           4691
#
#    num_following  num_tweets partei
# 0           3423       15100    fdp
# 1            659        1974    fdp
# 2           1251        2603    fdp
# 3           1057        4162    fdp
# 4           1147        1939    fdp

# %% [markdown]
# ## Match Aufgaben:
# ### Wahlkreise Shape und Menschen
# ### Menschen und twitter Profil
